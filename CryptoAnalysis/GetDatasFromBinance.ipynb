# %%
#Libraries

import requests
from datetime import datetime
import pandas as pd
from bs4 import BeautifulSoup
from requests.api import request
import os

# %% [markdown]
# ### Functions
#    * save_200_cryptocurrency : this function gets top 200 cryptocurrencies symbols from coinmarketcap using BeautifulSoup
#
#
#
#    * get_filename : this function gets name of our csv files which we're gonna get for each coin and our format is something like that --> BTC_USD_Binance_day_2021-03-13
#
#
#    * download_data : downloading data using cryptocompare API
#
#
#    * convert_to_dataframe : the datas come to us in json format. we convert them to pandas dataframe.
#
#
#    * save_datas : saving datas as csv file.

# %%
def save_200_cryptocurrency():
    
    resp = requests.get('https://coinmarketcap.com/all/views/all/')
    soup = BeautifulSoup(resp.text,'lxml')
    
    symbolsHtml = soup.findAll('td',class_="cmc-table__cell--sort-by__symbol")
    symbols = [symbol.text for symbol in symbolsHtml]

    with open('top_200_cryptocurrecny.txt','w') as file:
        file.writelines(f'{symbol}\n' for symbol in symbols)
        
    return symbols

# %%
symbolList = save_200_cryptocurrency()

# %%
def get_filename(symbol,to_symbol,exchange,datetime_interval,download_date):
    
    return '%s_%s_%s_%s_%s.csv' % (symbol, 
                                   to_symbol, 
                                   exchange, 
                                   datetime_interval, 
                                   download_date)

# %%
def download_data(symbol,to_symbol,exchange,datetime_interval):
    
    #Checking datetime_interval
    supported_intervals = {'minute','hour','day','week'}
    assert datetime_interval in supported_intervals,\
        'datetime_interval should be one of %s'% supported_intervals
    print('Downloading %s trading data for %s %s from %s' %
        (datetime_interval,symbol,to_symbol,exchange))
    
    download_date = datetime.now().date().isoformat()
    
    
    if not os.path.exists('RawDatas'):
        os.mkdir('RawDatas')
        
    if not os.path.exists("'RawDatas/'%s_%s_%s_%s_%s.csv'" % (symbol,
                                                              to_symbol, 
                                                              exchange, 
                                                              datetime_interval, 
                                                              download_date)):
        
        try:
            base_url = 'https://min-api.cryptocompare.com/data/histo'
            url = '%s%s' %(base_url,datetime_interval)
            params = {'fsym':symbol,'tsym':to_symbol,
                     'limit':2000,'aggregate':1}
            request = requests.get(url,params=params)
            data = request.json()
            print(f"We got {symbol}")
            return data
        
        except:
            print(f"There is a problem with {symbol}")

# %%
def convert_to_dataframe(data):
    
    df = pd.json_normalize(data,['Data'])
    df['datetime'] = pd.to_datetime(df.time,unit='s')
    df = df[['datetime','low','high','open','close','volumefrom','volumeto']]
    
    #Filtering empty data points
    indices = df[df.sum(axis=1) == 0].index
    print("Filterin %d empty datapoints " % indices.shape[0])
    df = df.drop(indices)
    
    return df

# %%
def save_datas(to_symbol,exchange,datetime_interval):
    
    for symbol in symbolList:
        
        data = download_data(symbol,to_symbol,exchange,datetime_interval)
        
        if data is not None:
            
            df = convert_to_dataframe(data)
            df = filter_empty_datapoints(df)
            
            current_datetime = datetime.now().date().isoformat()
            filename = get_filename(symbol,to_symbol,exchange,datetime_interval,current_datetime)
            df.to_csv(os.path.join("RawDatas/",filename),index=False)
            
        else:
            continue

# %%
save_datas(to_symbol='USD',exchange='Binance',datetime_interval='day')
# Out:
# Downloading day trading data for BTC USD from Binance
# We got BTC
# Filterin 0 empty datapoints
# Downloading day trading data for ETH USD from Binance
# We got ETH
# Filterin 0 empty datapoints
# Downloading day trading data for BNB USD from Binance
# We got BNB
# Filterin 699 empty datapoints
# Downloading day trading data for USDT USD from Binance
# We got USDT
# Filterin 0 empty datapoints
# Downloading day trading data for ADA USD from Binance
# We got ADA
# Filterin 741 empty datapoints
# Downloading day trading data for DOT USD from Binance
# We got DOT
# Filterin 1796 empty datapoints
# Downloading day trading data for XRP USD from Binance
# We got XRP
# Filterin 0 empty datapoints
# Downloading day trading data for UNI USD from Binance
# We got UNI
# Filterin 1823 empty datapoints
# Downloading day trading data for LTC USD from Binance
# We got LTC
# Filterin 0 empty datapoints
# Downloading day trading data for LINK USD from Binance
# We got LINK
# Filterin 731 empty datapoints
# Downloading day trading data for BCH USD from Binance
# We got BCH
# Filterin 680 empty datapoints
# Downloading day trading data for USDC USD from Binance
# We got USDC
# Filterin 1115 empty datapoints
# Downloading day trading data for XLM USD from Binance
# We got XLM
# Filterin 21 empty datapoints
# Downloading day trading data for WBTC USD from Binance
# We got WBTC
# Filterin 1057 empty datapoints
# Downloading day trading data for DOGE USD from Binance
# We got DOGE
# Filterin 0 empty datapoints
# Downloading day trading data for THETA USD from Binance
# We got THETA
# Filterin 862 empty datapoints
# Downloading day trading data for LUNA USD from Binance
# We got LUNA
# Filterin 520 empty datapoints
# Downloading day trading data for AAVE USD from Binance
# We got AAVE
# Filterin 1846 empty datapoints
# Downloading day trading data for CRO USD from Binance
# We got CRO
# Filterin 1272 empty datapoints
# Downloading day trading data for VET USD from Binance
# We got VET
# Filterin 724 empty datapoints
# Downloading day trading data for ATOM USD from Binance
# We got ATOM
# Filterin 1310 empty datapoints
# Downloading day trading data for XMR USD from Binance
# We got XMR
# Filterin 0 empty datapoints
# Downloading day trading data for BSV USD from Binance
# We got BSV
# Filterin 1155 empty datapoints
# Downloading day trading data for CHZ USD from Binance
# We got CHZ
# Filterin 1444 empty datapoints
# Downloading day trading data for AVAX USD from Binance
# We got AVAX
# Filterin 1828 empty datapoints
# Downloading day trading data for SOL USD from Binance
# We got SOL
# Filterin 1663 empty datapoints
# Downloading day trading data for EOS USD from Binance
# We got EOS
# Filterin 647 empty datapoints
# Downloading day trading data for MIOTA USD from Binance
# We got MIOTA
# Filterin 631 empty datapoints
# Downloading day trading data for TRX USD from Binance
# We got TRX
# Filterin 714 empty datapoints
# Downloading day trading data for FTT USD from Binance
# We got FTT
# Filterin 1373 empty datapoints
# Downloading day trading data for XEM USD from Binance
# We got XEM
# Filterin 0 empty datapoints
# Downloading day trading data for XTZ USD from Binance
# We got XTZ
# Filterin 642 empty datapoints
# Downloading day trading data for BUSD USD from Binance
# We got BUSD
# Filterin 1463 empty datapoints
# Downloading day trading data for NEO USD from Binance
# We got NEO
# Filterin 371 empty datapoints
# Downloading day trading data for ALGO USD from Binance
# We got ALGO
# Filterin 1369 empty datapoints
# Downloading day trading data for FIL USD from Binance
# We got FIL
# Filterin 1739 empty datapoints
# Downloading day trading data for SUSHI USD from Binance
# We got SUSHI
# Filterin 1807 empty datapoints
# Downloading day trading data for HT USD from Binance
# We got HT
# Filterin 890 empty datapoints
# Downloading day trading data for DAI USD from Binance
# We got DAI
# Filterin 821 empty datapoints
# Downloading day trading data for KSM USD from Binance
# We got KSM
# Filterin 1606 empty datapoints
# Downloading day trading data for EGLD USD from Binance
# We got EGLD
# Filterin 1809 empty datapoints
# Downloading day trading data for DASH USD from Binance
# We got DASH
# Filterin 0 empty datapoints
# Downloading day trading data for SNX USD from Binance
# We got SNX
# Filterin 940 empty datapoints
# Downloading day trading data for NEAR USD from Binance
# We got NEAR
# Filterin 1851 empty datapoints
# Downloading day trading data for GRT USD from Binance
# We got GRT
# Filterin 1915 empty datapoints
# Downloading day trading data for DCR USD from Binance
# We got DCR
# Filterin 121 empty datapoints
# Downloading day trading data for MKR USD from Binance
# We got MKR
# Filterin 784 empty datapoints
# Downloading day trading data for COMP USD from Binance
# We got COMP
# Filterin 1732 empty datapoints
# Downloading day trading data for MATIC USD from Binance
# We got MATIC
# Filterin 1317 empty datapoints
# Downloading day trading data for LEO USD from Binance
# We got LEO
# Filterin 1345 empty datapoints
# Downloading day trading data for HBAR USD from Binance
# We got HBAR
# Filterin 1460 empty datapoints
# Downloading day trading data for TFUEL USD from Binance
# We got TFUEL
# Filterin 1283 empty datapoints
# Downloading day trading data for ZIL USD from Binance
# We got ZIL
# Filterin 862 empty datapoints
# Downloading day trading data for ZEC USD from Binance
# We got ZEC
# Filterin 403 empty datapoints
# Downloading day trading data for ENJ USD from Binance
# We got ENJ
# Filterin 772 empty datapoints
# Downloading day trading data for RVN USD from Binance
# We got RVN
# Filterin 939 empty datapoints
# Downloading day trading data for BTT USD from Binance
# We got BTT
# Filterin 1229 empty datapoints
# Downloading day trading data for ETC USD from Binance
# We got ETC
# Filterin 307 empty datapoints
# Downloading day trading data for CAKE USD from Binance
# We got CAKE
# Filterin 1983 empty datapoints
# Downloading day trading data for MANA USD from Binance
# We got MANA
# Filterin 666 empty datapoints
# Downloading day trading data for BTCB USD from Binance
# We got BTCB
# Filterin 1709 empty datapoints
# Downloading day trading data for RUNE USD from Binance
# We got RUNE
# Filterin 1770 empty datapoints
# Downloading day trading data for YFI USD from Binance
# We got YFI
# Filterin 1775 empty datapoints
# Downloading day trading data for NEXO USD from Binance
# We got NEXO
# Filterin 974 empty datapoints
# Downloading day trading data for CHSB USD from Binance
# We got CHSB
# Filterin 875 empty datapoints
# Downloading day trading data for UMA USD from Binance
# We got UMA
# Filterin 1718 empty datapoints
# Downloading day trading data for BNT USD from Binance
# We got BNT
# Filterin 287 empty datapoints
# Downloading day trading data for CEL USD from Binance
# We got CEL
# Filterin 1032 empty datapoints
# Downloading day trading data for BAT USD from Binance
# We got BAT
# Filterin 618 empty datapoints
# Downloading day trading data for REN USD from Binance
# We got REN
# Filterin 913 empty datapoints
# Downloading day trading data for VGX USD from Binance
# We got VGX
# Filterin 1528 empty datapoints
# Downloading day trading data for FLOW USD from Binance
# We got FLOW
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# TypeError: Addition/subtraction of integers and integer-arrays with Timestamp is no longer supported.  Instead of adding/subtracting `n`, use `n * obj.freq`
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# ...
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-22-83688e36852b> in <module>
# ----> 1 save_datas(to_symbol='USD',exchange='Binance',datetime_interval='day')
#
# <ipython-input-21-0d5160a5d58c> in save_datas(to_symbol, exchange, datetime_interval)
#       8
#       9             df = convert_to_dataframe(data)
# ---> 10             df = filter_empty_datapoints(df)
#      11
#      12             current_datetime = datetime.now().date().isoformat()
#
# <ipython-input-20-932d9eafaf02> in filter_empty_datapoints(df)
#       1 def filter_empty_datapoints(df):
#       2
# ----> 3     indices = df[df.sum(axis=1) == 0].index
#       4     print("Filterin %d empty datapoints " % indices.shape[0])
#       5     df = df.drop(indices)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11411                 name, axis=axis, level=level, skipna=skipna, min_count=min_count
#   11412             )
# > 11413         return self._reduce(
#   11414             func,
#   11415             name=name,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    8645
#    8646             try:
# -> 8647                 result = func(values)
#    8648
#    8649             except TypeError:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in func(values)
#    8566                 return extract_array(values)._reduce(name, skipna=skipna, **kwds)
#    8567             else:
# -> 8568                 return op(values, axis=axis, skipna=skipna, **kwds)
#    8569
#    8570         def _get_data(axis_matters):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/nanops.py in nansum(values, axis, skipna, min_count, mask)
#     507     elif is_timedelta64_dtype(dtype):
#     508         dtype_sum = np.float64
# --> 509     the_sum = values.sum(axis, dtype=dtype_sum)
#     510     the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     511
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.integer_op_not_supported()
#
# SystemError: <class 'TypeError'> returned a result with an error set
